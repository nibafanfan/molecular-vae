# %% [markdown]
# <a href="https://colab.research.google.com/github/aksub99/molecular-vae/blob/master/Molecular_VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import gzip
import pandas
import h5py
import numpy as np
from __future__ import print_function
import argparse
import os
import h5py
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn import model_selection

# %%
def one_hot_array(i, n):
    return map(int, [ix == i for ix in range(n)])

def one_hot_index(vec, charset):
    return map(charset.index, vec)

def from_one_hot_array(vec):
    oh = np.where(vec == 1)
    if oh[0].shape == (0, ):
        return None
    return int(oh[0][0])

def decode_smiles_from_indexes(vec, charset):
    return b"".join(map(lambda x: charset[x], vec)).strip()

def load_dataset(filename, split = True):
    h5f = h5py.File(filename, 'r')
    if split:
        data_train = h5f['data_train'][:]
    else:
        data_train = None
    data_test = h5f['data_test'][:]
    charset =  h5f['charset'][:]
    h5f.close()
    if split:
        return (data_train, data_test, charset)
    else:
        return (data_test, charset)

# %%
class MolecularVAE(nn.Module):
    def __init__(self):
        super(MolecularVAE, self).__init__()

        self.conv_1 = nn.Conv1d(120, 9, kernel_size=9)
        self.conv_2 = nn.Conv1d(9, 9, kernel_size=9)
        self.conv_3 = nn.Conv1d(9, 10, kernel_size=11)
        self.linear_0 = nn.Linear(70, 435)
        self.linear_1 = nn.Linear(435, 292)
        self.linear_2 = nn.Linear(435, 292)

        self.linear_3 = nn.Linear(292, 292)
        self.gru = nn.GRU(292, 501, 3, batch_first=True)
        self.linear_4 = nn.Linear(501, 33)
        
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax()

    def encode(self, x):
        x = self.relu(self.conv_1(x))
        x = self.relu(self.conv_2(x))
        x = self.relu(self.conv_3(x))
        x = x.view(x.size(0), -1)
        x = F.selu(self.linear_0(x))
        return self.linear_1(x), self.linear_2(x)

    def sampling(self, z_mean, z_logvar):
        epsilon = 1e-2 * torch.randn_like(z_logvar)
        return torch.exp(0.5 * z_logvar) * epsilon + z_mean

    def decode(self, z):
        z = F.selu(self.linear_3(z))
        z = z.view(z.size(0), 1, z.size(-1)).repeat(1, 120, 1)
        output, hn = self.gru(z)
        out_reshape = output.contiguous().view(-1, output.size(-1))
        y0 = F.softmax(self.linear_4(out_reshape), dim=1)
        y = y0.contiguous().view(output.size(0), -1, y0.size(-1))
        return y

    def forward(self, x):
        z_mean, z_logvar = self.encode(x)
        z = self.sampling(z_mean, z_logvar)
        return self.decode(z), z_mean, z_logvar

# %%
# !rm -R 'molecular-vae'
# !git clone https://github.com/aksub99/molecular-vae.git
import zipfile
zip_ref = zipfile.ZipFile('molecular-vae/data/processed.zip', 'r')
zip_ref.extractall('molecular-vae/data/')
zip_ref.close()
# Out:
# rm: cannot remove 'molecular-vae': No such file or directory
# Cloning into 'molecular-vae'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 188 (delta 0), reused 1 (delta 0), pack-reused 185
# Receiving objects: 100% (188/188), 2.99 MiB | 26.14 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
def vae_loss(x_decoded_mean, x, z_mean, z_logvar):
    xent_loss = F.binary_cross_entropy(x_decoded_mean, x, size_average=False)
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp())
    return xent_loss + kl_loss

data_train, data_test, charset = load_dataset('molecular-vae/data/processed.h5')
data_train = torch.utils.data.TensorDataset(torch.from_numpy(data_train))
train_loader = torch.utils.data.DataLoader(data_train, batch_size=250, shuffle=True)

torch.manual_seed(42)

epochs = 30
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = MolecularVAE().to(device)
optimizer = optim.Adam(model.parameters())

def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, data in enumerate(train_loader):
        data = data[0].to(device)
        optimizer.zero_grad()
        output, mean, logvar = model(data)
        
        if batch_idx==0:
              inp = data.cpu().numpy()
              outp = output.cpu().detach().numpy()
              lab = data.cpu().numpy()
              print("Input:")
              print(decode_smiles_from_indexes(map(from_one_hot_array, inp[0]), charset))
              print("Label:")
              print(decode_smiles_from_indexes(map(from_one_hot_array, lab[0]), charset))
              sampled = outp[0].reshape(1, 120, len(charset)).argmax(axis=2)[0]
              print("Output:")
              print(decode_smiles_from_indexes(sampled, charset))
        
        loss = vae_loss(output, data, mean, logvar)
        loss.backward()
        train_loss += loss
        optimizer.step()
#         if batch_idx % 100 == 0:
#             print(f'{epoch} / {batch_idx}\t{loss:.4f}')
    print('train', train_loss / len(train_loader.dataset))
    return train_loss / len(train_loader.dataset)

for epoch in range(1, epochs + 1):
    train_loss = train(epoch)
    print('trainloss', train_loss)
# Out:
# Input:
# b'c1ccc(cc1)CS(=O)(=O)NCc2ccccn2'
# Label:
# b'c1ccc(cc1)CS(=O)(=O)NCc2ccccn2'
# Output:
# b'rrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr'
# train tensor(151.1784, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(151.1784, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CC(=O)c1ccc(cc1)OCC(=O)OC'
# Label:
# b'CC(=O)c1ccc(cc1)OCC(=O)OC'
# Output:
# b'Cccccccccccccccccccccc'
# train tensor(120.9563, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(120.9563, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1ccc(cc1)n2c(c(c3c2ccc(c3)O)C(=O)C)C'
# Label:
# b'Cc1ccc(cc1)n2c(c(c3c2ccc(c3)O)C(=O)C)C'
# Output:
# b'CccccccccccccccccccccccccccccccccccC'
# train tensor(121.1522, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(121.1522, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1nc(cs1)c2nc(cc(n2)OC)COC'
# Label:
# b'Cc1nc(cs1)c2nc(cc(n2)OC)COC'
# Output:
# b'C1ccccccccccccccccccccccC'
# train tensor(118.0314, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(118.0314, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1cc(nc(n1)N2CC[NH2+]CC2)C'
# Label:
# b'Cc1cc(nc(n1)N2CC[NH2+]CC2)C'
# Output:
# b'C1ccccccccccccccccccccccc)'
# train tensor(112.9887, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(112.9887, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1ccc(cc1)CCC(=O)OCC(=O)Nc2ccc(cc2)F'
# Label:
# b'c1ccc(cc1)CCC(=O)OCC(=O)Nc2ccc(cc2)F'
# Output:
# b'CCcccccccccccccccccccccccccccccccc)))'
# train tensor(111.5405, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(111.5405, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1cc(n2c(n1)nc(n2)SCC(=O)Nc3ccc(cc3)F)C'
# Label:
# b'Cc1cc(n2c(n1)nc(n2)SCC(=O)Nc3ccc(cc3)F)C'
# Output:
# b'CCccccccccccccccccccccccccccccccccc)))C'
# train tensor(108.5217, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(108.5217, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CN(C)c1cccc(c1CNC(=O)Nc2ccccc2)N(C)C'
# Label:
# b'CN(C)c1cccc(c1CNC(=O)Nc2ccccc2)N(C)C'
# Output:
# b'C1ccccccccccccccccccccccccccc)))))C'
# train tensor(107.1554, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(107.1554, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1cc(ccc1C(c2ccc(cc2)Cl)O)Cl'
# Label:
# b'c1cc(ccc1C(c2ccc(cc2)Cl)O)Cl'
# Output:
# b'C1cccccc1cccccccccc()CCCCC)C'
# train tensor(101.9003, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(101.9003, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1c(cc(o1)C(C)(C)C)C(=O)N2CCC[C@@H]2C(=O)[O-]'
# Label:
# b'Cc1c(cc(o1)C(C)(C)C)C(=O)N2CCC[C@@H]2C(=O)[O-]'
# Output:
# b'C11ccccccc1ccccc(CCCCCCCCCCCCCCCCCCCCCCCCCCCCCC'
# train tensor(97.7025, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(97.7025, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'C[C@H]1CCCN(C1)C(=O)c2ccccc2Br'
# Label:
# b'C[C@H]1CCCN(C1)C(=O)c2ccccc2Br'
# Output:
# b'CCCC@CCCCCCCCC((cccccccccccc)C'
# train tensor(95.5417, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(95.5417, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1c2c(c(c(c1Br)O)Br)sc(=O)o2'
# Label:
# b'Cc1c2c(c(c(c1Br)O)Br)sc(=O)o2'
# Output:
# b'Cc1ccccccc1)cccccccc2)CCCC)C'
# train tensor(91.9892, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(91.9892, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'COc1cc(c(cc1OC)N)C(=O)OC'
# Label:
# b'COc1cc(c(cc1OC)N)C(=O)OC'
# Output:
# b'COc1ccccccc1)CCC)OOCC))C'
# train tensor(89.2387, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(89.2387, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CC1=C(Sc2ccc(cc2N1)C(F)(F)F)C(=O)OCC(C)C'
# Label:
# b'CC1=C(Sc2ccc(cc2N1)C(F)(F)F)C(=O)OCC(C)C'
# Output:
# b'CC(C(O)cccccccc11)))))))))))CCCCCCCCCCC)CC'
# train tensor(88.0501, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(88.0501, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1cc(c(c(=O)n1CC(=O)c2ccccc2)C#N)COC'
# Label:
# b'Cc1cc(c(c(=O)n1CC(=O)c2ccccc2)C#N)COC'
# Output:
# b'Cc1ccc(c(c1)CC(==O))ccccccccc2)CCOO)C'
# train tensor(84.2848, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(84.2848, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CSc1cccc(c1)NC(=O)CCSc2ccc(cc2)Cl'
# Label:
# b'CSc1cccc(c1)NC(=O)CCSc2ccc(cc2)Cl'
# Output:
# b'COc1ccc(cc1)CCC=OOO)cccccccc2))C'
# train tensor(82.7094, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(82.7094, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CCOC(=O)c1cnn(c1C)c2ccccc2'
# Label:
# b'CCOC(=O)c1cnn(c1C)c2ccccc2'
# Output:
# b'CCOC(=O)c1cccc11))ccccccc2'
# train tensor(80.0187, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(80.0187, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1cc(ccc1C(=O)Nc2ccc(cc2)Cl)Cl'
# Label:
# b'c1cc(ccc1C(=O)Nc2ccc(cc2)Cl)Cl'
# Output:
# b'c1cc(ccc1C(=O))c2cccccc2)CC))l'
# train tensor(78.0427, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(78.0427, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'Cc1cccc(c1)n2c(ccc2c3cccs3)CCC(=O)[O-]'
# Label:
# b'Cc1cccc(c1)n2c(ccc2c3cccs3)CCC(=O)[O-]'
# Output:
# b'Cc1cccccc1)c2cccccccccccc3)CC=OOOOO-]'
# train tensor(77.0482, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(77.0482, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1ccc(cc1)c2ncc(o2)CSc3nc4ccccc4o3'
# Label:
# b'c1ccc(cc1)c2ncc(o2)CSc3nc4ccccc4o3'
# Output:
# b'c1ccc(cc1)c2ccccccccccncccccccccc'
# train tensor(74.8045, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(74.8045, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CCC[C@H](C)C(=O)NCc1ccc2c(c1)OCO2'
# Label:
# b'CCC[C@H](C)C(=O)NCc1ccc2c(c1)OCO2'
# Output:
# b'CC[C@@H](CCCC(=O)111cccccc11CCCC'
# train tensor(73.0283, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(73.0283, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'C[C@@]1(C2(CCCCC2)OC(=O)N1C)O'
# Label:
# b'C[C@@]1(C2(CCCCC2)OC(=O)N1C)O'
# Output:
# b'C[C@H]1CCCCCCCCCCC)))OOCC)C'
# train tensor(71.7117, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(71.7117, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CCOc1ccc(cc1)c2c3ccccc3c([nH+]n2)N4CCOCC4'
# Label:
# b'CCOc1ccc(cc1)c2c3ccccc3c([nH+]n2)N4CCOCC4'
# Output:
# b'CCOc1ccc(cc1)C(=ccccccccc22CCCCCCCCCCCCCC'
# train tensor(70.8292, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(70.8292, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1ccc2cc(ccc2c1)C(=O)Nc3ccc4c(c3)OCCO4'
# Label:
# b'c1ccc2cc(ccc2c1)C(=O)Nc3ccc4c(c3)OCCO4'
# Output:
# b'c1ccc2c(cc)cccn))CC=O)Ncccccccc4)CCC)C'
# train tensor(70.0194, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(70.0194, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1ccc2c(c1)c(n[nH]c2=O)C(=O)NC3CC3'
# Label:
# b'c1ccc2c(c1)c(n[nH]c2=O)C(=O)NC3CC3'
# Output:
# b'c1ccc2c(c1)c(ccn2)CCCC))))CCCCCC3'
# train tensor(68.1745, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(68.1745, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1cc2c(cc1F)c3c([nH]2)CC[NH+](C3)Cc4ccc(cc4Cl)Cl'
# Label:
# b'c1cc2c(cc1F)c3c([nH]2)CC[NH+](C3)Cc4ccc(cc4Cl)Cl'
# Output:
# b'c1cc(cc(c1)c(cccnnn[[HHH]]]]]]]3cccccccccc4C)C'
# train tensor(67.2478, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(67.2478, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'C[NH+](C)C[C@H](Cn1c2ccc(cc2c3c1ccc(c3)Cl)Cl)O'
# Label:
# b'C[NH+](C)C[C@H](Cn1c2ccc(cc2c3c1ccc(c3)Cl)Cl)O'
# Output:
# b'C[C@H]1CCCCC@@H]1ccccccccccccccccccccc)OOOOOC'
# train tensor(66.2668, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(66.2668, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'CCN1C(=C([C@@H](NC1=O)c2cccc(c2)C(F)(F)F)C(=O)OC)C'
# Label:
# b'CCN1C(=C([C@@H](NC1=O)c2cccc(c2)C(F)(F)F)C(=O)OC)C'
# Output:
# b'CC1CC(CCCCCC((O)C(==)))c2cccccc2)))(())))))))))))'
# train tensor(65.0607, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(65.0607, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'COc1ccc(cc1OC)C(=O)N2CCN(CC2)S(=O)(=O)C'
# Label:
# b'COc1ccc(cc1OC)C(=O)N2CCN(CC2)S(=O)(=O)C'
# Output:
# b'COc1ccc(cc1)CC(==O)CCCCCCCCCCCCCC(OOOOC'
# train tensor(64.0873, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(64.0873, device='cuda:0', grad_fn=<DivBackward0>)
# Input:
# b'c1ccc(cc1)Cn2c3c(c(ncn3)Nc4ccccc4F)nn2'
# Label:
# b'c1ccc(cc1)Cn2c3c(c(ncn3)Nc4ccccc4F)nn2'
# Output:
# b'c1ccc(cc1)C222ccccccccccccccccccccc4))'
# train tensor(62.9923, device='cuda:0', grad_fn=<DivBackward0>)
# trainloss tensor(62.9923, device='cuda:0', grad_fn=<DivBackward0>)
